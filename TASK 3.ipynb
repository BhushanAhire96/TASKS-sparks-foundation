# %% [markdown]
# # Exploratory data analysis
# Perform EDA on SampleSuperstore Dataset
#
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# import warnings
# warnings.filterwarnings('ignore')

# %%
import os
os.chdir(r'C:\Users\Bhakti Aaher\Untitled Folder 2')

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
#display database columns
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#it shows all info.about database like all columns,null value count,datatype etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.drop_duplicates(keep='first',inplace=True)
df.head(20)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %% [markdown]
# # No of unique values in each column

# %%
for i in df.columns: print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %% [markdown]
# # check for null values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
corr_mat = df.corr()
corr_mat
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
#it plots pair wise relationship on the dataset.and other ralation showed using scatterplot
sns.pairplot(df)

# %% [markdown]
# # Bivarite Analysis

# %% [markdown]
# For category

# %%
plt.figure(figsize=[10,5],dpi=80)
df.groupby('Category')['Sales'].mean().plot(kind='bar')
df.groupby('Category')['Sales'].mean()
# Out:
# Category
# Furniture          350.002981
# Office Supplies    119.550107
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=80)
df.groupby('Category')['Discount'].mean().plot(kind='bar')
df.groupby('Category')['Discount'].mean()
# Out:
# Category
# Furniture          0.174027
# Office Supplies    0.157385
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=80)
df.groupby('Category')['Profit'].mean().plot(kind='bar')
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Furniture           8.697740
# Office Supplies    20.353403
# Technology         78.752002
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=80)
df.groupby('Category')['Quantity'].mean().plot(kind='bar')
df.groupby('Category')['Quantity'].mean()
# Out:
# Category
# Furniture          3.786591
# Office Supplies    3.802562
# Technology         3.756903
# Name: Quantity, dtype: float64

# %% [markdown]
# # for sub-categories
# it displays sales by subcategories

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Sub-Category')['Sales'].mean().plot(kind='barh',color='violet')
df.groupby('Sub-Category')['Sales'].mean()
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Art              34.096896
# Binders         133.645972
# Bookcases       503.859633
# Chairs          532.971969
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      95.902745
# Labels           34.283504
# Machines       1645.553313
# Paper            57.560075
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Sub-Category')['Quantity'].mean().plot(kind='barh',color='violet')
df.groupby('Sub-Category')['Quantity'].mean()
# Out:
# Sub-Category
# Accessories    3.840000
# Appliances     3.710300
# Art            3.768553
# Binders        3.923127
# Bookcases      3.807018
# Chairs         3.822764
# Copiers        3.441176
# Envelopes      3.566929
# Fasteners      4.211982
# Furnishings    3.723849
# Labels         3.845730
# Machines       3.826087
# Paper          3.785136
# Phones         3.699663
# Storage        3.732861
# Supplies       3.405263
# Tables         3.890282
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Sub-Category')['Profit'].mean().plot(kind='barh',color='violet')
df.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Accessories     54.111788
# Appliances      38.922758
# Art              8.207059
# Binders         19.860710
# Bookcases      -15.230509
# Chairs          43.198582
# Copiers        817.909190
# Envelopes       27.418019
# Fasteners        4.375660
# Furnishings     13.653476
# Labels          15.224193
# Machines        29.432669
# Paper           24.977365
# Phones          50.073938
# Storage         25.152277
# Supplies        -6.258418
# Tables         -55.565771
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Sub-Category')['Discount'].mean().plot(kind='barh',color='violet')
df.groupby('Sub-Category')['Discount'].mean()
# Out:
# Sub-Category
# Accessories    0.078452
# Appliances     0.166524
# Art            0.074969
# Binders        0.372011
# Bookcases      0.211140
# Chairs         0.170244
# Copiers        0.161765
# Envelopes      0.080315
# Fasteners      0.082028
# Furnishings    0.138494
# Labels         0.068871
# Machines       0.306087
# Paper          0.074908
# Phones         0.154556
# Storage        0.074704
# Supplies       0.076842
# Tables         0.261285
# Name: Discount, dtype: float64

# %% [markdown]
# # for Region
# Here we see region wise sales

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Region')['Sales'].mean().plot(kind='barh',color='black')
plt.xlabel('Sales')
df.groupby('Region')['Sales'].mean()
# Out:
# Region
# Central    215.947759
# East       238.465798
# South      241.803645
# West       227.139254
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Region')['Discount'].mean().plot(kind='barh',color='black')
plt.xlabel('Discount')
df.groupby('Region')['Discount'].mean()
# Out:
# Region
# Central    0.240250
# East       0.145343
# South      0.147253
# West       0.109615
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=[10,5],dpi=100)
df.groupby('Region')['Profit'].mean().plot(kind='barh',color='black')
plt.xlabel('Profit')
df.groupby('Region')['Profit'].mean()
# Out:
# Region
# Central    17.100421
# East       32.163905
# South      28.857673
# West       33.927281
# Name: Profit, dtype: float64

# %% [markdown]
# # Multivarite analysis
#
# For Category

# %%
sns.barplot(x='Sales',y='Category',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Category'>

# %%
sns.barplot(x='Profit',y='Category',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Category'>

# %%
sns.barplot(x='Discount',y='Category',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Category'>

# %%
# For Sub-Category

# %%
plt.figure(figsize = (15,15))
sns.barplot(x='Sales', y='Sub-Category', hue='Region', data = df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Sub-Category'>

# %%
#here we see profit of subcategoriesn region wise
plt.figure(figsize=(15,15))
sns.barplot(x='Profit',y='Sub-Category',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Sub-Category'>

# %%
here we see discout of subcategories by resion wise
plt.figure(figsize=(15,15))
sns.barplot(x='Discount',y='Sub-Category',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Sub-Category'>

# %%
#we use heatmap here,using heatmap visualise correlation between columns 
fig,axes =plt.subplots(1,1,figsize=(12,7))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# # Disribuion plot

# %%
sns.distplot(df['Sales'],bins=5)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(df['Profit'],bins=5)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df['Discount'],bins=5)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Density'>

# %%
sns.distplot(df['Quantity'],bins=5)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %%
Important Inhights
-The features profit and discount are highly related.
-Over less quantity of products also the sales were high.
-The home office provides highest sales provide highest sales followed by slight variation.
